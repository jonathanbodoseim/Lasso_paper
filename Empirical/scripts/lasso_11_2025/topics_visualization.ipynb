# %%
import pandas as pd
import numpy as np
import os
import pickle
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base_dir = Path(os.getenv("LASSO_OUTPUT_DIR", "output"))
features_path = Path("output") / "features.pkl"
response_path = Path("output") / "response.pkl"

with features_path.open("rb") as f:
    X = pickle.load(f)

# %%
#plot all of the features over time
plt.figure(figsize=(15, 10))
for i in range(X.shape[1]):
    plt.plot(X.iloc[:, i])
plt.xlabel('Time')
plt.ylabel('Feature Value')
plt.title('Features Over Time')
plt.show()

# %%
X.columns
# Out:
# Index(['Natural disasters', 'Internet', 'Soft drinks', 'Mobile devices',
#        'Profits', 'M&A', 'Changes', 'Police/crime', 'Research',
#        'Executive pay',
#        ...
#        'European politics', 'Size', 'NASD', 'Mexico', 'Retail',
#        'Long/short term', 'Wide range', 'Lawsuits', 'UK', 'Revenue growth'],
#       dtype='object', length=180)

# %%
#visualize correlation matrix of features
correlation_matrix = pd.DataFrame(X).corr()
fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap='coolwarm', center=0, ax=ax)
ax.set_title('Feature Correlation Matrix')
plt.show()
